# %% [markdown]
# # TASK 4: Short Written Summary
#
# **Summary**
# ShopEase performed well in 2024, with Beauty as the highest-grossing category. Peak sales occurred during festive months. However, East and West regions show high cancellation rates (35 each), possibly due to failed transactions or slow shipping. Priority should be reducing cancellations in these areas by improving payment alerts and quicker delivery.
#
# **The single most important insight from the data**
# Beauty brings in the highest revenue among all categories.
#
# **One year-on-year observation (2023 vs 2024)**
# Year-over-year: Revenue increased in 2024, with strong performance during festive season months.
#
# **One underperforming area — region, category, or product — and a possible reason**
# Underperforming area: East and West regions recorded the most cancellations. This may happen because of payment failures or buyers changing their mind.
# Possible reason is Customers in East and West might prefer COD or Net Banking, which sometimes fail, or they may experience slower delivery times.
#
# **One actionable recommendation for the business**
# Actionable recommendation: Investigate cancellation reasons in East and West regions. Send order confirmation texts and provide faster shipping choices to lower cancellations.
